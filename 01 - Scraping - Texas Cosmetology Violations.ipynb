# %% [markdown]
# # Texas Cosmetologist Violations
#
# Texas has a system for [searching for license violations](https://www.tdlr.texas.gov/cimsfo/fosearch.asp). You're going to search for cosmetologists!
#
# > You can use the classwork notebook and also [my Everything scraping reference](https://jonathansoma.com/everything/scraping)

# %% [markdown]
# ## Setup: Import what you'll need to scrape the page
#
# We'll be using either Playwrightfor this, *not* requests.

# %%
from playwright.async_api import async_playwright

playwright = await async_playwright().start()
browser = await playwright.chromium.launch(headless = False)
page = await browser.new_page()

# %% [markdown]
# ## Starting your search
#
# Starting from [here](https://www.tdlr.texas.gov/cimsfo/fosearch.asp), search for cosmetologist violations for people with the last name **Nguyen**.

# %%
await page.goto("https://www.tdlr.texas.gov/cimsfo/fosearch.asp")
# Out:
# <Response url='https://www.tdlr.texas.gov/cimsfo/fosearch.asp' request=<Request url='https://www.tdlr.texas.gov/cimsfo/fosearch.asp' method='GET'>>

# %%
await page.locator("#pht_status").select_option('cosmetologist')
## why I can't get the option 'cosmetologist'?

# %%
await page.get_by_text("cosmetologist").click()
## this way doesn't work either?
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 await page.get_by_text("cosmetologist").click()
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/playwright/async_api/_generated.py:15706, in Locator.click(self, modifiers, position, delay, button, click_count, timeout, force, no_wait_after, trial)
#   15619 async def click(
#   15620     self,
#   15621     *,
#    (...)
#   15632     trial: typing.Optional[bool] = None
#   15633 ) -> None:
#   15634     """Locator.click
#   15635
#   15636     Click an element.
#    (...)
#   15702         to `false`. Useful to wait until the element is ready for the action without performing it.
#   15703     """
#   15705     return mapping.from_maybe_impl(
# > 15706         await self._impl_obj.click(
#   15707             modifiers=mapping.to_impl(modifiers),
#   15708             position=position,
#   15709             delay=delay,
#   15710             button=button,
#   15711             clickCount=click_count,
#   15712             timeout=timeout,
#   15713             force=force,
#   15714             noWaitAfter=no_wait_after,
#   15715             trial=trial,
#   15716         )
#   15717     )
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/playwright/_impl/_locator.py:159, in Locator.click(self, modifiers, position, delay, button, clickCount, timeout, force, noWaitAfter, trial)
#     146 async def click(
#     147     self,
#     148     modifiers: List[KeyboardModifier] = None,
#    (...)
#     156     trial: bool = None,
#     157 ) -> None:
#     158     params = locals_to_params(locals())
# --> 159     return await self._frame.click(self._selector, strict=True, **params)
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/playwright/_impl/_frame.py:484, in Frame.click(self, selector, modifiers, position, delay, button, clickCount, timeout, force, noWaitAfter, strict, trial)
#     470 async def click(
#     471     self,
#     472     selector: str,
#    (...)
#     482     trial: bool = None,
#     483 ) -> None:
# --> 484     await self._channel.send("click", locals_to_params(locals()))
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/playwright/_impl/_connection.py:62, in Channel.send(self, method, params)
#      61 async def send(self, method: str, params: Dict = None) -> Any:
# ---> 62     return await self._connection.wrap_api_call(
#      63         lambda: self.inner_send(method, params, False)
#      64     )
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/playwright/_impl/_connection.py:492, in Connection.wrap_api_call(self, cb, is_internal)
#     490 self._api_zone.set(_extract_stack_trace_information_from_stack(st, is_internal))
#     491 try:
# --> 492     return await cb()
#     493 finally:
#     494     self._api_zone.set(None)
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/playwright/_impl/_connection.py:100, in Channel.inner_send(self, method, params, return_as_dict)
#      98 if not callback.future.done():
#      99     callback.future.cancel()
# --> 100 result = next(iter(done)).result()
#     101 # Protocol now has named return values, assume result is one level deeper unless
#     102 # there is explicit ambiguity.
#     103 if not result:
#
# Error: Error: strict mode violation: get_by_text("cosmetologist") resolved to 7 elements:
#     1) <a href="/cosmet/cosmet.htm">Cosmetologists</a> aka get_by_role("banner").get_by_text("Cosmetologists").first
#     2) <a href="/App_Online/default.asp?LicenseType=COS">Cosmetologists</a> aka get_by_role("banner").get_by_text("Cosmetologists").nth(1)
#     3) <a href="/ce/cecos.htm">Cosmetologists</a> aka get_by_role("banner").get_by_text("Cosmetologists").nth(2)
#     4) <option value="COS">Cosmetologists</option> aka get_by_label("Search by License Program Type")
#     5) <a href="/cosmet/cosmet.htm">Cosmetologists</a> aka locator("#dat-menu-list-inner").get_by_text("Cosmetologists").first
#     6) <a href="/App_Online/default.asp?LicenseType=COS">Cosmetologists</a> aka locator("#dat-menu-list-inner").get_by_text("Cosmetologists").nth(1)
#     7) <a href="/ce/cecos.htm">Cosmetologists</a> aka locator("#dat-menu-list-inner").get_by_text("Cosmetologists").nth(2)

# %%
#fill out the last name
await page.locator("#pht_lnm").fill("Nguyen")

# %%
#click on search
await page.get_by_text("Search", exact=True).click()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[15], line 2
#       1 #click on search
# ----> 2 await page.get_by_text("Search", exact=True).click()
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/playwright/async_api/_generated.py:15706, in Locator.click(self, modifiers, position, delay, button, click_count, timeout, force, no_wait_after, trial)
#   15619 async def click(
#   15620     self,
#   15621     *,
#    (...)
#   15632     trial: typing.Optional[bool] = None
#   15633 ) -> None:
#   15634     """Locator.click
#   15635
#   15636     Click an element.
#    (...)
#   15702         to `false`. Useful to wait until the element is ready for the action without performing it.
#   15703     """
#   15705     return mapping.from_maybe_impl(
# > 15706         await self._impl_obj.click(
#   15707             modifiers=mapping.to_impl(modifiers),
#   15708             position=position,
#   15709             delay=delay,
#   15710             button=button,
#   15711             clickCount=click_count,
#   15712             timeout=timeout,
#   15713             force=force,
#   15714             noWaitAfter=no_wait_after,
#   15715             trial=trial,
#   15716         )
#   15717     )
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/playwright/_impl/_locator.py:159, in Locator.click(self, modifiers, position, delay, button, clickCount, timeout, force, noWaitAfter, trial)
#     146 async def click(
#     147     self,
#     148     modifiers: List[KeyboardModifier] = None,
#    (...)
#     156     trial: bool = None,
#     157 ) -> None:
#     158     params = locals_to_params(locals())
# --> 159     return await self._frame.click(self._selector, strict=True, **params)
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/playwright/_impl/_frame.py:484, in Frame.click(self, selector, modifiers, position, delay, button, clickCount, timeout, force, noWaitAfter, strict, trial)
#     470 async def click(
#     471     self,
#     472     selector: str,
#    (...)
#     482     trial: bool = None,
#     483 ) -> None:
# --> 484     await self._channel.send("click", locals_to_params(locals()))
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/playwright/_impl/_connection.py:62, in Channel.send(self, method, params)
#      61 async def send(self, method: str, params: Dict = None) -> Any:
# ---> 62     return await self._connection.wrap_api_call(
#      63         lambda: self.inner_send(method, params, False)
#      64     )
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/playwright/_impl/_connection.py:492, in Connection.wrap_api_call(self, cb, is_internal)
#     490 self._api_zone.set(_extract_stack_trace_information_from_stack(st, is_internal))
#     491 try:
# --> 492     return await cb()
#     493 finally:
#     494     self._api_zone.set(None)
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/playwright/_impl/_connection.py:100, in Channel.inner_send(self, method, params, return_as_dict)
#      98 if not callback.future.done():
#      99     callback.future.cancel()
# --> 100 result = next(iter(done)).result()
#     101 # Protocol now has named return values, assume result is one level deeper unless
#     102 # there is explicit ambiguity.
#     103 if not result:
#
# Error: Error: strict mode violation: get_by_text("Search", exact=True) resolved to 3 elements:
#     1) <input type="submit" value="Search"/> aka get_by_role("banner").get_by_role("button", name="Search")
#     2) <input name="B1" type="submit" tabindex="11" value="Sea…/> aka locator("input[name=\"B1\"]")
#     3) <input type="submit" value="Search"/> aka locator("#dat-menu-list-inner").get_by_text("Search", exact=True)

# %% [markdown]
# ## Scraping
#
# Once you are on the results page, do this. **I step you through things bit by bit, so it's going to be a little different than we did in class.** Also, no `pd.read_html` allowed because this isn't reaaallly tabular data (or there's just too much to clean up).
#
# Once you've loaded the page: **what selector are you going to do use to find the data?** In class we used things like `.article` or `.head-list`.
#
# > You honestly can do this all with Playwright, no BeautifulSoup involved! But we didn't cover that in class so you should stick to this method:
# >
# > ```python
# > html = await page.content()
# > doc = BeautifulSoup(html)
# > ```

# %%
await page.goto("https://www.tdlr.texas.gov/cimsfo/fosearch_results.asp")
from bs4 import BeautifulSoup
html = await page.content()
doc = BeautifulSoup(html)

# %% [markdown]
# ### Grab the rows, loop through each result and print the entire row
#
# It's probably too many rows to do all at once: once you have a list, use `[:10]` to only show the first ten! For example, if you saved the table rows into `results` you might do something like this:
#
# ```python
# for result in results[:10]:
#     print("------")
#     print(result)
# ```
#
# Although you'd want to print out the text from the row (I give example output below).

# %%
results = doc.select("tr")
for result in results[:10]:
    print("------")
    print(result.text)
## okay I am gonna finish this here.... I rewatched the lecture recordings and felt like I got nearly everything
## but I have tried my best to go through the questions to here.
# Out:
# ------
#
#
# Administrative Orders - Search
#
#                                         This search includes Orders issued by the Commission or Executive Director assessing a sanction,
#                                         an administrative penalty or both for violations of TDLR's program laws and rules.
#                                         This search covers Orders issued during the current and most recent past two fiscal years.
#                                         TDLR's fiscal years begin on September 1st and end on August 31st of each year.
#                                         For information on obtaining copies of Orders not included in this search,
#                                         please submit a written request for the Order(s) to
#
# TDLR Records Center.
#
#
#
#                                         Email Questions/Comments to customer.service@tdlr.texas.gov
#
#
#
#
#
#
#
#                                                         Please enter at least one (1) parameter; using multiple parameters is recommended for a faster retrieval.
#
#
#
#
#
#
# Search by License Program Type
#
#
#
#
#
# Choose One (Optional)
# Air Conditioning Contractors and Technicians
# Architectural Barriers
# Athletic Trainers
# Auctioneers
# Barbers
# Boilers
# Code Enforcement Officers
# Combative Sports
# Cosmetologists
# Dietitians
# Driver Education and Safety
# Dyslexia Therapists and Practicioners
# Electricians
# Elevators, Escalators
# Elevator Inspectors
# Elevator Contractors
# For Profit Legal Service Contracts
# Hearing Instrument Fitters and Dispensers
# Industrialized Housing and Buildings
# Laser Hair Removal
# Licensed Breeders
# Massage Therapy
# Midwives
# Mold Assessors and Remediators
# Motor Fuel Metering and Quality
# Offender Education Providers
# Orthotists and Prosthetists
# Podiatry
# Polygraph Examiners
# Professional Employer Organization
# Property Tax Consultants
# Property Tax Professionals
# Registered Accessibility Specialist
# Sanitarians
# Service Contract Providers
# Speech-Language Pathologists and Audiologists
# Transportation Network Companies
# Tow Truck Companies
# Used Automotive Parts Recyclers
# Vehicle Storage Facilities
# Water Well Drillers, Pump Installers
# Weather Modification
#
#
#
#
#
# Search by License #
#
#
#
#
#
#
# 										                contains
#
#
#
#
#
# Search by Last Name
#
#
#
#
#
#
# 									                    begins with
#
#
#
#
#
# Search by First Name
#
#
#
#
#
# Motor Fuel Metering and Quality
# Offender Education Providers
# Orthotists and Prosthetists
# Podiatry
# Polygraph Examiners
# Professional Employer Organization
# Property Tax Consultants
# Property Tax Professionals
# Registered Accessibility Specialist
# Sanitarians
# Service Contract Providers
# Speech-Language Pathologists and Audiologists
# Transportation Network Companies
# Tow Truck Companies
# Used Automotive Parts Recyclers
# Vehicle Storage Facilities
# Water Well Drillers, Pump Installers
# Weather Modification
#
#
#
# ------
#
#
# Search by License #
#
#
# ------
#
#
#
#
# 										                contains
#
#
#
# ------
#
#
# Search by Last Name
#
#
# ------
#
#
#
#
# 									                    begins with
#
#
#
# ------
#
#
# Search by First Name
#
#
# ------
#
#
#
#
# 										                begins with

# %% [markdown]
# The result should look something like this:
#
# ```
# Name and Location Order Basis for Order
# NGUYEN, THANH
# City: FRISCO
# County: COLLIN
# Zip Code: 75034
#
#
# License #: 790672
#
# Complaint # COS20210004784 Date: 11/16/2021
#
# Respondent is assessed an administrative penalty in the amount of $1,875. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day, the Department is charging 2 violations; Respondent operated a cosmetology salon without the appropriate license.
# NGUYEN, LONG D
# City: SAN SABA
# County: SAN SABA
# Zip Code: 76877
# ```

# %% [markdown]
# ### Loop through each result and print each person's name
#
# You'll probably get an error because the first one doesn't have a name. How do you make that not happen?! If you want to ignore an error, you use code like this:
#
# ```python
# try:
#    # try to do something
# except:
#    print("It didn't work')
# ```
#
# It should help you out. If you don't want to print anything when there's an error, you can type `pass` instead of the `print` statement.
#
# **Why doesn't the first one have a name?**
#
# Output should look like this:
#
# ```
# Doesn't have a name
# NGUYEN, THANH
# NGUYEN, LONG D
# NGUYEN, LUCIE HUONG
# NGUYEN, CHINH
# NGUYEN, JIMMY
# ```
#
# * *Tip: The name has a class you can use. The class name is reused in a lot of places, but because it's the first one you don't have to worry about that!*
# * *Tip: Instead of searching across the entire page – like `doc.select_one` – you should be doing your searching just inside of each **row** (I used this technique in the beginning of class with BeautifulSoup when we were scraping the books page)*

# %% [markdown]
# ## Loop through each result, printing each violation description ("Basis for order")
#
# Your results should look something like:
#
# ```
# Doesn't have a violation
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day, the Department is charging 2 violations; Respondent operated a cosmetology salon without the appropriate license.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect manicure tables prior to use for each client.
# ...
# ```
#
# > - *Tip: You'll get an error even if you're ALMOST right - which row is causing the problem?*
# > - *Tip: Or I guess you could just skip the one with the problem using try/except...*

# %% [markdown]
# ## Loop through each result, printing the complaint number
#
# Output should look similar to this:
#
# ```
# Doesn't have a complaint number
# COS20210004784
# COS20210009745
# COS20210011484
# ...
# ```
#
# - *Tip: Think about the order of the elements. Can you count from the opposite direction than you normally do?*

# %% [markdown]
# ## Saving the results
#
# ### Loop through each result to create a list of dictionaries
#
# Each dictionary must contain
#
# - Person's name
# - Violation description
# - Violation number
# - License Numbers
# - Zip Code
# - County
# - City
#
# Create a new dictionary for each result (except the header).
#
# Based on what you print out, the output might look something like:
#
# ```
# This row is broken: Name and Location Order Basis for Order
# {'name': 'NGUYEN, THANH', 'city': 'FRISCO', 'county': 'COLLIN', 'zip_code': '75034', 'complaint_no': 'COS20210004784', 'license_numbers': '790672', 'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day, the Department is charging 2 violations; Respondent operated a cosmetology salon without the appropriate license.'}
# {'name': 'NGUYEN, LONG D', 'city': 'SAN SABA', 'county': 'SAN SABA', 'zip_code': '76877', 'complaint_no': 'COS20210009745', 'license_numbers': '760420, 1620583', 'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect manicure tables prior to use for each client.'}
# ```
#
# > _**Tip:** Depending on how you do this, you might want to figure out how to search for "next siblings" or "following siblings"_

# %% [markdown]
# ### Save that to a CSV named `output.csv`
#
# The dataframe should look something like...
#
# |index|name|city|county|zip_code|complaint_no|license_numbers|complaint|
# |---|---|---|---|---|---|---|---|
# |0|NGUYEN, THANH|FRISCO|COLLIN|75034|COS20210004784|790672|Respondent failed to clean and sanitize whirlp...|
# |1|NGUYEN, LONG D|SAN SABA|SAN SABA|76877|COS20210009745|760420, 1620583|Respondent failed to keep a record of the date...|
#
#
# - *Tip: If you send a list of dictionaries to `pd.DataFrame(...)`, it will create a dataframe out of that list!*

# %% [markdown]
# ### Open the CSV file and examine the first few. Make sure you didn't save an extra weird unnamed column.
